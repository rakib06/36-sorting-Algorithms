# %% [markdown]
# <a href="https://colab.research.google.com/github/rakib06/36-sorting-Algorithms/blob/master/Machine_Learning_Foundations_pynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Ep -1. What is ML?

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras
model = tf.keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])
model.compile(optimizer='sgd', loss='mean_squared_error')
xs = np.array([1, 2, 3, 4, 5, 6, 10])
ys =np.array([100000, 150000, 200000, 250000, 300000, 350000, 550000])
model.fit(xs, ys, epochs=500)
print(model.predict([7.0]))
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 2ms/step - loss: 92859416576.0000
# Epoch 2/500
# 1/1 [==============================] - 0s 9ms/step - loss: 18329251840.0000
# Epoch 3/500
# 1/1 [==============================] - 0s 4ms/step - loss: 3911606528.0000
# Epoch 4/500
# 1/1 [==============================] - 0s 1ms/step - loss: 1119327872.0000
# Epoch 5/500
# 1/1 [==============================] - 0s 1ms/step - loss: 575355776.0000
# Epoch 6/500
# 1/1 [==============================] - 0s 2ms/step - loss: 466234432.0000
# Epoch 7/500
# 1/1 [==============================] - 0s 2ms/step - loss: 441251744.0000
# Epoch 8/500
# 1/1 [==============================] - 0s 1ms/step - loss: 432584128.0000
# Epoch 9/500
# 1/1 [==============================] - 0s 1ms/step - loss: 427112896.0000
# Epoch 10/500
# 1/1 [==============================] - 0s 1ms/step - loss: 422302208.0000
# Epoch 11/500
# 1/1 [==============================] - 0s 1ms/step - loss: 417659744.0000
# ...

# %%
|
